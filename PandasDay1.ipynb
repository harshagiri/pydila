# %% [markdown]
# #Series

# %%
import pandas as pd
import numpy as np

mylist = [100,150,200,300]
ps1 = pd.Series(mylist)
print(ps1)
print("Type of Panda Series is ",type(ps1))
print("\nIndicies are ",ps1.index)
print("\nValue are ",ps1.values)
print("\nType of values is ",type(ps1.values))
print("\nShape is ",ps1.shape)
print("\nNdim is ",ps1.ndim)
print("\nSize is ",ps1.size)
print("\nDtype is ",ps1.dtype)
# Out:
# 0    100
# 1    150
# 2    200
# 3    300
# dtype: int64
# Type of Panda Series is  <class 'pandas.core.series.Series'>
#
# Indicies are  RangeIndex(start=0, stop=4, step=1)
#
# Value are  [100 150 200 300]
#
# Type of values is  <class 'numpy.ndarray'>
#
# Shape is  (4,)
#
# Ndim is  1
#
# Size is  4
#
# Dtype is  int64

# %%
indexlist = ["Tata", "Birla", "Adani", "Wipro"]
ps2 = pd.Series(mylist, index = indexlist)
print(ps2)
# Out:
# Tata     100
# Birla    150
# Adani    200
# Wipro    300
# dtype: int64

# %%
md1 = {'Tata':200, 'Birla':400, 'Adani':600, 'Volva':500,'Wipro':800, 'Infy':300, 'HCL':100}
ps3 = pd.Series(md1)
print(ps3)
# Out:
# Tata     200
# Birla    400
# Adani    600
# Volva    500
# Wipro    800
# Infy     300
# HCL      100
# dtype: int64

# %% [markdown]
# #Series Access

# %%
print(ps3[ (ps3>200) & (ps3<600)])
# Out:
# Birla    400
# Volva    500
# Infy     300
# dtype: int64

# %%
# Describe prints summary statistics of the Series
ps3.describe()
# Out:
# count      7.000000
# mean     414.285714
# std      241.029538
# min      100.000000
# 25%      250.000000
# 50%      400.000000
# 75%      550.000000
# max      800.000000
# dtype: float64

# %%
print(ps3)
print("max is {}".format(ps3.max()))
print("min is {}".format(ps3.min()))
print("standard deviation is {}".format(ps3.std()))
print("median is {}".format(ps3.median()))
print("varience is {}".format(ps3.var()))
# Out:
# Tata     200
# Birla    400
# Adani    600
# Volva    500
# Wipro    800
# Infy     300
# HCL      100
# dtype: int64
# max is 800
# min is 100
# standard deviation is 241.02953780654786
# median is 400.0
# varience is 58095.238095238084

# %%
ps3.value_counts()
# Out:
# 300    1
# 200    1
# 800    1
# 500    1
# 600    1
# 100    1
# 400    1
# dtype: int64

# %%
#Data Frames
        Vol Exp Rev
Tata 100 101 102
Birla 103
Wipro
Infy
Adani

# %%
dfvalues = np.arange(100, 100+15).reshape(5,3)
print(dfvalues)
# Out:
# [[100 101 102]
#  [103 104 105]
#  [106 107 108]
#  [109 110 111]
#  [112 113 114]]

# %%
row_label_list = ['Tata', 'Birla', 'Wipro', 'Infy', 'Adani']
col_label_list = ['Vol', 'Exp', 'Rev']
df1 = pd.DataFrame(data = dfvalues, index = row_label_list, columns = col_label_list)
df1
# Out:
#        Vol  Exp  Rev
# Tata   100  101  102
# Birla  103  104  105
# Wipro  106  107  108
# Infy   109  110  111
# Adani  112  113  114

# %%
print("\nindex is ",df1.index)
print("\nValues are ",df1.values)
print("\nColumns are ",df1.columns)
print("\nDimension is ",df1.ndim)
print("\nShape is ",df1.shape)
print(df1.describe())
# Out:
# index is  Index(['Tata', 'Birla', 'Wipro', 'Infy', 'Adani'], dtype='object')
#
# Values are  [[100 101 102]
#  [103 104 105]
#  [106 107 108]
#  [109 110 111]
#  [112 113 114]]
#
# Columns are  Index(['Vol', 'Exp', 'Rev'], dtype='object')
#
# Dimension is  2
#
# Shape is  (5, 3)
#               Vol         Exp         Rev
# count    5.000000    5.000000    5.000000
# mean   106.000000  107.000000  108.000000
# std      4.743416    4.743416    4.743416
# min    100.000000  101.000000  102.000000
# 25%    103.000000  104.000000  105.000000
# 50%    106.000000  107.000000  108.000000
# 75%    109.000000  110.000000  111.000000
# max    112.000000  113.000000  114.000000

# %%
md1 = {
    'Vol': [200,201,202,203,204],
    'Rev': [300,301,302,303,304],
    'Exp': [400,401,402,403,404]
}
df2 = pd.DataFrame(md1, index = row_label_list)
df2
# Out:
#        Vol  Rev  Exp
# Tata   200  300  400
# Birla  201  301  401
# Wipro  202  302  402
# Infy   203  303  403
# Adani  204  304  404

# %%
print(type(df2))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df2.describe()
# Out:
#               Vol         Rev         Exp
# count    5.000000    5.000000    5.000000
# mean   202.000000  302.000000  402.000000
# std      1.581139    1.581139    1.581139
# min    200.000000  300.000000  400.000000
# 25%    201.000000  301.000000  401.000000
# 50%    202.000000  302.000000  402.000000
# 75%    203.000000  303.000000  403.000000
# max    204.000000  304.000000  404.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Tata to Adani
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Vol     5 non-null      int64
#  1   Rev     5 non-null      int64
#  2   Exp     5 non-null      int64
# dtypes: int64(3)
# memory usage: 160.0+ bytes

# %%
#Dataframe Access

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
df1
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance       899  917.0  674  Pub    1443  Mum
# Bombay_Sporting      925  839.8  615  Pvt     154  Mum
# Kolkata_FMCG         900  874.4  676  Pub    1379  Kol
# NCR_Leagles          931  863.5  605  Pub    1935  NCR
# Chennai_Shipping     992  821.0  665  Pub    1154  Che
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che
# Indi_Services        954  733.0  609  Gov   13023  NCR

# %%
df1.head()
# Out:
#                   Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance    899  917.0  674  Pub    1443  Mum
# Bombay_Sporting   925  839.8  615  Pvt     154  Mum
# Kolkata_FMCG      900  874.4  676  Pub    1379  Kol
# NCR_Leagles       931  863.5  605  Pub    1935  NCR
# Chennai_Shipping  992  821.0  665  Pub    1154  Che

# %%
df1.head(3)
# Out:
#                  Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance   899  917.0  674  Pub    1443  Mum
# Bombay_Sporting  925  839.8  615  Pvt     154  Mum
# Kolkata_FMCG     900  874.4  676  Pub    1379  Kol

# %%
df1.tail()
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
# Chennai_Shipping     992  821.0  665  Pub    1154  Che
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che
# Indi_Services        954  733.0  609  Gov   13023  NCR

# %%
df1.tail(3)
df1.to_csv('lds1.csv')

# %%
dfh = pd.read_csv('lds1.csv')
dfh
# Out:
#             Unnamed: 0  Vol    Rev  Exp Catg  EmpCnt   HQ
# 0       Bombay_Finance  899  917.0  674  Pub    1443  Mum
# 1      Bombay_Sporting  925  839.8  615  Pvt     154  Mum
# 2         Kolkata_FMCG  900  874.4  676  Pub    1379  Kol
# 3          NCR_Leagles  931  863.5  605  Pub    1935  NCR
# 4     Chennai_Shipping  992  821.0  665  Pub    1154  Che
# 5    Bangalore_Systems  931  881.6  650  Gov    1361  Blr
# 6  Bangalore_Breweries  966  805.0  895  Pvt     119  Blr
# 7    Chennai_Chemicals  966  863.2  608  Pub    1656  Che
# 8        Indi_Services  954  733.0  609  Gov   13023  NCR

# %%
dfh.describe(include='all')
# Out:
#           Unnamed: 0         Vol         Rev         Exp Catg        EmpCnt  \
# count              9    9.000000    9.000000    9.000000    9      9.000000
# unique             9         NaN         NaN         NaN    3           NaN
# top     Kolkata_FMCG         NaN         NaN         NaN  Pub           NaN
# freq               1         NaN         NaN         NaN    5           NaN
# mean             NaN  940.444444  844.277778  666.333333  NaN   2469.333333
# std              NaN   31.460734   53.389788   90.689029  NaN   4006.439036
# min              NaN  899.000000  733.000000  605.000000  NaN    119.000000
# 25%              NaN  925.000000  821.000000  609.000000  NaN   1154.000000
# 50%              NaN  931.000000  863.200000  650.000000  NaN   1379.000000
# 75%              NaN  966.000000  874.400000  674.000000  NaN   1656.000000
# max              NaN  992.000000  917.000000  895.000000  NaN  13023.000000
#
#          HQ
# count     9
# unique    5
# top     NCR
# freq      2
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN

# %%
#DF Access

# %%
dfh['Vol']
# Out:
# 0    899
# 1    925
# 2    900
# 3    931
# 4    992
# 5    931
# 6    966
# 7    966
# 8    954
# Name: Vol, dtype: int64

# %%
#df1[ [vector of column indicies ]] 
# Data frame serach take column index
df1[['Vol','Rev','HQ']]
# Out:
#                      Vol    Rev   HQ
# Bombay_Finance       899  917.0  Mum
# Bombay_Sporting      925  839.8  Mum
# Kolkata_FMCG         900  874.4  Kol
# NCR_Leagles          931  863.5  NCR
# Chennai_Shipping     992  821.0  Che
# Bangalore_Systems    931  881.6  Blr
# Bangalore_Breweries  966  805.0  Blr
# Chennai_Chemicals    966  863.2  Che
# Indi_Services        954  733.0  NCR

# %%
#slicing takes row index
df1[ 'Bombay_Finance':'Bangalore_Systems']
# Out:
#                    Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance     899  917.0  674  Pub    1443  Mum
# Bombay_Sporting    925  839.8  615  Pvt     154  Mum
# Kolkata_FMCG       900  874.4  676  Pub    1379  Kol
# NCR_Leagles        931  863.5  605  Pub    1935  NCR
# Chennai_Shipping   992  821.0  665  Pub    1154  Che
# Bangalore_Systems  931  881.6  650  Gov    1361  Blr

# %%
df1['Kolkata_FMCG':'Kolkata_FMCG']
# Out:
#               Vol    Rev  Exp Catg  EmpCnt   HQ
# Kolkata_FMCG  900  874.4  676  Pub    1379  Kol

# %%
#iLOC based Access

# %%
df1.iloc[0]
# Out:
# Vol        899
# Rev        917
# Exp        674
# Catg       Pub
# EmpCnt    1443
# HQ         Mum
# Name: Bombay_Finance, dtype: object

# %%
df1.iloc[0,0]
# Out:
# 899

# %%
df1.iloc[-1,-1]
# Out:
# 'NCR'

# %%
df1.index
# Out:
# Index(['Bombay_Finance', 'Bombay_Sporting', 'Kolkata_FMCG', 'NCR_Leagles',
#        'Chennai_Shipping', 'Bangalore_Systems', 'Bangalore_Breweries',
#        'Chennai_Chemicals', 'Indi_Services'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Vol', 'Rev', 'Exp', 'Catg', 'EmpCnt', 'HQ'], dtype='object')

# %%
df1.iloc[0:3]
# Out:
#                  Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance   899  917.0  674  Pub    1443  Mum
# Bombay_Sporting  925  839.8  615  Pvt     154  Mum
# Kolkata_FMCG     900  874.4  676  Pub    1379  Kol

# %%
df1.iloc[0:3, 2:5]
# Out:
#                  Exp Catg  EmpCnt
# Bombay_Finance   674  Pub    1443
# Bombay_Sporting  615  Pvt     154
# Kolkata_FMCG     676  Pub    1379

# %%
df1.iloc[ [0,-1,2,3] ]
# Out:
#                 Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance  899  917.0  674  Pub    1443  Mum
# Indi_Services   954  733.0  609  Gov   13023  NCR
# Kolkata_FMCG    900  874.4  676  Pub    1379  Kol
# NCR_Leagles     931  863.5  605  Pub    1935  NCR

# %%
df1.iloc[ [0,-1,2,3], [0,-1,-2] ]
# Out:
#                 Vol   HQ  EmpCnt
# Bombay_Finance  899  Mum    1443
# Indi_Services   954  NCR   13023
# Kolkata_FMCG    900  Kol    1379
# NCR_Leagles     931  NCR    1935

# %%
r_mask = df1['Vol'] > 931
df1[r_mask]
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
# Chennai_Shipping     992  821.0  665  Pub    1154  Che
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che
# Indi_Services        954  733.0  609  Gov   13023  NCR

# %%
df1[df1.Catg=='Pub']
# Out:
#                    Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance     899  917.0  674  Pub    1443  Mum
# Kolkata_FMCG       900  874.4  676  Pub    1379  Kol
# NCR_Leagles        931  863.5  605  Pub    1935  NCR
# Chennai_Shipping   992  821.0  665  Pub    1154  Che
# Chennai_Chemicals  966  863.2  608  Pub    1656  Che

# %%
df1[ (df1.Catg=='Pub') & (df1.Vol > 940) ]
# Out:
#                    Vol    Rev  Exp Catg  EmpCnt   HQ
# Chennai_Shipping   992  821.0  665  Pub    1154  Che
# Chennai_Chemicals  966  863.2  608  Pub    1656  Che

# %%
#LOC Based Access - lable based access

# %%
df1.loc['Bombay_Finance']
# Out:
# Vol        899
# Rev        917
# Exp        674
# Catg       Pub
# EmpCnt    1443
# HQ         Mum
# Name: Bombay_Finance, dtype: object

# %%
df1.get('Vol')
# Out:
# Bombay_Finance         899
# Bombay_Sporting        925
# Kolkata_FMCG           900
# NCR_Leagles            931
# Chennai_Shipping       992
# Bangalore_Systems      931
# Bangalore_Breweries    966
# Chennai_Chemicals      966
# Indi_Services          954
# Name: Vol, dtype: int64

# %%
df1.loc[:, df1.columns[2]]
# Out:
# Bombay_Finance         674
# Bombay_Sporting        615
# Kolkata_FMCG           676
# NCR_Leagles            605
# Chennai_Shipping       665
# Bangalore_Systems      650
# Bangalore_Breweries    895
# Chennai_Chemicals      608
# Indi_Services          609
# Name: Exp, dtype: int64

# %%
#Sorting

# %%
df1
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance       899  917.0  674  Pub    1443  Mum
# Bombay_Sporting      925  839.8  615  Pvt     154  Mum
# Kolkata_FMCG         900  874.4  676  Pub    1379  Kol
# NCR_Leagles          931  863.5  605  Pub    1935  NCR
# Chennai_Shipping     992  821.0  665  Pub    1154  Che
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che
# Indi_Services        954  733.0  609  Gov   13023  NCR

# %%
df1.sort_index()
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr
# Bombay_Finance       899  917.0  674  Pub    1443  Mum
# Bombay_Sporting      925  839.8  615  Pvt     154  Mum
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che
# Chennai_Shipping     992  821.0  665  Pub    1154  Che
# Indi_Services        954  733.0  609  Gov   13023  NCR
# Kolkata_FMCG         900  874.4  676  Pub    1379  Kol
# NCR_Leagles          931  863.5  605  Pub    1935  NCR

# %%
df1.sort_index(axis =1)
# Out:
#                     Catg  EmpCnt  Exp   HQ    Rev  Vol
# Bombay_Finance       Pub    1443  674  Mum  917.0  899
# Bombay_Sporting      Pvt     154  615  Mum  839.8  925
# Kolkata_FMCG         Pub    1379  676  Kol  874.4  900
# NCR_Leagles          Pub    1935  605  NCR  863.5  931
# Chennai_Shipping     Pub    1154  665  Che  821.0  992
# Bangalore_Systems    Gov    1361  650  Blr  881.6  931
# Bangalore_Breweries  Pvt     119  895  Blr  805.0  966
# Chennai_Chemicals    Pub    1656  608  Che  863.2  966
# Indi_Services        Gov   13023  609  NCR  733.0  954

# %%
#inplace = true: Change the incoming data frame, do not create a new data set and reply
df1.sort_index(axis = 1, inplace=True)
df1
# Out:
#                     Catg  EmpCnt  Exp   HQ    Rev  Vol
# Bombay_Finance       Pub    1443  674  Mum  917.0  899
# Bombay_Sporting      Pvt     154  615  Mum  839.8  925
# Kolkata_FMCG         Pub    1379  676  Kol  874.4  900
# NCR_Leagles          Pub    1935  605  NCR  863.5  931
# Chennai_Shipping     Pub    1154  665  Che  821.0  992
# Bangalore_Systems    Gov    1361  650  Blr  881.6  931
# Bangalore_Breweries  Pvt     119  895  Blr  805.0  966
# Chennai_Chemicals    Pub    1656  608  Che  863.2  966
# Indi_Services        Gov   13023  609  NCR  733.0  954

# %%
df1.sort_index(axis = 1, inplace=False, ascending=False)
# Out:
#                      Vol    Rev   HQ  Exp  EmpCnt Catg
# Bombay_Finance       899  917.0  Mum  674    1443  Pub
# Bombay_Sporting      925  839.8  Mum  615     154  Pvt
# Kolkata_FMCG         900  874.4  Kol  676    1379  Pub
# NCR_Leagles          931  863.5  NCR  605    1935  Pub
# Chennai_Shipping     992  821.0  Che  665    1154  Pub
# Bangalore_Systems    931  881.6  Blr  650    1361  Gov
# Bangalore_Breweries  966  805.0  Blr  895     119  Pvt
# Chennai_Chemicals    966  863.2  Che  608    1656  Pub
# Indi_Services        954  733.0  NCR  609   13023  Gov

# %%
df1.sort_values(by='Vol')
# Out:
#                     Catg  EmpCnt  Exp   HQ    Rev  Vol
# Bombay_Finance       Pub    1443  674  Mum  917.0  899
# Kolkata_FMCG         Pub    1379  676  Kol  874.4  900
# Bombay_Sporting      Pvt     154  615  Mum  839.8  925
# NCR_Leagles          Pub    1935  605  NCR  863.5  931
# Bangalore_Systems    Gov    1361  650  Blr  881.6  931
# Indi_Services        Gov   13023  609  NCR  733.0  954
# Bangalore_Breweries  Pvt     119  895  Blr  805.0  966
# Chennai_Chemicals    Pub    1656  608  Che  863.2  966
# Chennai_Shipping     Pub    1154  665  Che  821.0  992

# %%
df1.sort_values(by=['Vol','Rev'], ascending=[False,False])
# Out:
#                     Catg  EmpCnt  Exp   HQ    Rev  Vol
# Chennai_Shipping     Pub    1154  665  Che  821.0  992
# Chennai_Chemicals    Pub    1656  608  Che  863.2  966
# Bangalore_Breweries  Pvt     119  895  Blr  805.0  966
# Indi_Services        Gov   13023  609  NCR  733.0  954
# Bangalore_Systems    Gov    1361  650  Blr  881.6  931
# NCR_Leagles          Pub    1935  605  NCR  863.5  931
# Bombay_Sporting      Pvt     154  615  Mum  839.8  925
# Kolkata_FMCG         Pub    1379  676  Kol  874.4  900
# Bombay_Finance       Pub    1443  674  Mum  917.0  899

# %%
#Ranking

# %%
df1.Vol.rank(ascending=True)
# Out:
# Bombay_Finance         1.0
# Bombay_Sporting        3.0
# Kolkata_FMCG           2.0
# NCR_Leagles            4.5
# Chennai_Shipping       9.0
# Bangalore_Systems      4.5
# Bangalore_Breweries    7.5
# Chennai_Chemicals      7.5
# Indi_Services          6.0
# Name: Vol, dtype: float64

# %%
df1.Vol.rank(ascending=False, method='dense')
# Out:
# Bombay_Finance         7.0
# Bombay_Sporting        5.0
# Kolkata_FMCG           6.0
# NCR_Leagles            4.0
# Chennai_Shipping       1.0
# Bangalore_Systems      4.0
# Bangalore_Breweries    2.0
# Chennai_Chemicals      2.0
# Indi_Services          3.0
# Name: Vol, dtype: float64

# %%
df1['ExpRank'] = df1.Exp.rank(ascending=True, method='first')
df1
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ  ExpRank
# Bombay_Finance       899  917.0  674  Pub    1443  Mum      7.0
# Bombay_Sporting      925  839.8  615  Pvt     154  Mum      4.0
# Kolkata_FMCG         900  874.4  676  Pub    1379  Kol      8.0
# NCR_Leagles          931  863.5  605  Pub    1935  NCR      1.0
# Chennai_Shipping     992  821.0  665  Pub    1154  Che      6.0
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr      5.0
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr      9.0
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che      2.0
# Indi_Services        954  733.0  609  Gov   13023  NCR      3.0

# %%
#Concatenation

# %%
df11 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds11.csv')
print(df11)
df12 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds12.csv')
print(df12)
# Out:
#                    Vol    Rev  Exp Catg  EmpCnt   HQ
# NCR_Leagles        931  863.5  605  Pub    1935  NCR
# Chennai_Shipping   992  821.0  665  Pub    1154  Che
# Bangalore_Systems  931  881.6  650  Gov    1361  Blr
# Bombay_Finance     899  917.0  674  Pub    1443  Mum
# Bombay_Sporting    925  839.8  615  Pvt     154  Mum
#                      Vol    Rev  Expn  Grp  EmpCnt   HQ
# Bombay_Sporting      925  839.8   615  Pvt     154  Mum
# Kolkata_FMCG         900  874.4   676  Pub    1379  Kol
# Bangalore_Breweries  966  805.0   895  Pvt     119  Blr
# Chennai_Chemicals    966  863.2   608  Pub    1656  Che
# Indi_Services        954  733.0   609  Gov   13023  NCR

# %%
dfc = pd.concat(objs = (df11, df12), axis=0, join = 'outer')
dfc
# Out:
#                      Vol    Rev    Exp Catg  EmpCnt   HQ   Expn  Grp
# NCR_Leagles          931  863.5  605.0  Pub    1935  NCR    NaN  NaN
# Chennai_Shipping     992  821.0  665.0  Pub    1154  Che    NaN  NaN
# Bangalore_Systems    931  881.6  650.0  Gov    1361  Blr    NaN  NaN
# Bombay_Finance       899  917.0  674.0  Pub    1443  Mum    NaN  NaN
# Bombay_Sporting      925  839.8  615.0  Pvt     154  Mum    NaN  NaN
# Bombay_Sporting      925  839.8    NaN  NaN     154  Mum  615.0  Pvt
# Kolkata_FMCG         900  874.4    NaN  NaN    1379  Kol  676.0  Pub
# Bangalore_Breweries  966  805.0    NaN  NaN     119  Blr  895.0  Pvt
# Chennai_Chemicals    966  863.2    NaN  NaN    1656  Che  608.0  Pub
# Indi_Services        954  733.0    NaN  NaN   13023  NCR  609.0  Gov

# %%
dfc = pd.concat(objs = (df11, df12), axis=0, join = 'inner')
dfc
# Out:
#                      Vol    Rev  EmpCnt   HQ
# NCR_Leagles          931  863.5    1935  NCR
# Chennai_Shipping     992  821.0    1154  Che
# Bangalore_Systems    931  881.6    1361  Blr
# Bombay_Finance       899  917.0    1443  Mum
# Bombay_Sporting      925  839.8     154  Mum
# Bombay_Sporting      925  839.8     154  Mum
# Kolkata_FMCG         900  874.4    1379  Kol
# Bangalore_Breweries  966  805.0     119  Blr
# Chennai_Chemicals    966  863.2    1656  Che
# Indi_Services        954  733.0   13023  NCR

# %%
dfc = pd.concat(objs = (df11, df12), axis=1, join = 'outer')
dfc
# Out:
#                        Vol    Rev    Exp Catg  EmpCnt   HQ    Vol    Rev  \
# NCR_Leagles          931.0  863.5  605.0  Pub  1935.0  NCR    NaN    NaN
# Chennai_Shipping     992.0  821.0  665.0  Pub  1154.0  Che    NaN    NaN
# Bangalore_Systems    931.0  881.6  650.0  Gov  1361.0  Blr    NaN    NaN
# Bombay_Finance       899.0  917.0  674.0  Pub  1443.0  Mum    NaN    NaN
# Bombay_Sporting      925.0  839.8  615.0  Pvt   154.0  Mum  925.0  839.8
# Kolkata_FMCG           NaN    NaN    NaN  NaN     NaN  NaN  900.0  874.4
# Bangalore_Breweries    NaN    NaN    NaN  NaN     NaN  NaN  966.0  805.0
# Chennai_Chemicals      NaN    NaN    NaN  NaN     NaN  NaN  966.0  863.2
# Indi_Services          NaN    NaN    NaN  NaN     NaN  NaN  954.0  733.0
#
#                       Expn  Grp   EmpCnt   HQ
# NCR_Leagles            NaN  NaN      NaN  NaN
# Chennai_Shipping       NaN  NaN      NaN  NaN
# Bangalore_Systems      NaN  NaN      NaN  NaN
# Bombay_Finance         NaN  NaN      NaN  NaN
# Bombay_Sporting      615.0  Pvt    154.0  Mum
# Kolkata_FMCG         676.0  Pub   1379.0  Kol
# Bangalore_Breweries  895.0  Pvt    119.0  Blr
# Chennai_Chemicals    608.0  Pub   1656.0  Che
# Indi_Services        609.0  Gov  13023.0  NCR

# %%
dfc = pd.concat(objs = (df11, df12), axis=0, join = 'outer', keys = ['d11','d12'])
dfc
# Out:
#                          Vol    Rev    Exp Catg  EmpCnt   HQ   Expn  Grp
# d11 NCR_Leagles          931  863.5  605.0  Pub    1935  NCR    NaN  NaN
#     Chennai_Shipping     992  821.0  665.0  Pub    1154  Che    NaN  NaN
#     Bangalore_Systems    931  881.6  650.0  Gov    1361  Blr    NaN  NaN
#     Bombay_Finance       899  917.0  674.0  Pub    1443  Mum    NaN  NaN
#     Bombay_Sporting      925  839.8  615.0  Pvt     154  Mum    NaN  NaN
# d12 Bombay_Sporting      925  839.8    NaN  NaN     154  Mum  615.0  Pvt
#     Kolkata_FMCG         900  874.4    NaN  NaN    1379  Kol  676.0  Pub
#     Bangalore_Breweries  966  805.0    NaN  NaN     119  Blr  895.0  Pvt
#     Chennai_Chemicals    966  863.2    NaN  NaN    1656  Che  608.0  Pub
#     Indi_Services        954  733.0    NaN  NaN   13023  NCR  609.0  Gov

# %%
dfc.loc[('d12','Bombay_Sporting')]
# Out:
# Vol         925
# Rev       839.8
# Exp         NaN
# Catg        NaN
# EmpCnt      154
# HQ          Mum
# Expn        615
# Grp         Pvt
# Name: (d12, Bombay_Sporting), dtype: object

# %%
dfc.index
# Out:
# MultiIndex([('d11',         'NCR_Leagles'),
#             ('d11',    'Chennai_Shipping'),
#             ('d11',   'Bangalore_Systems'),
#             ('d11',      'Bombay_Finance'),
#             ('d11',     'Bombay_Sporting'),
#             ('d12',     'Bombay_Sporting'),
#             ('d12',        'Kolkata_FMCG'),
#             ('d12', 'Bangalore_Breweries'),
#             ('d12',   'Chennai_Chemicals'),
#             ('d12',       'Indi_Services')],
#            )

# %%
dfc.columns
# Out:
# Index(['Vol', 'Rev', 'Exp', 'Catg', 'EmpCnt', 'HQ', 'Expn', 'Grp'], dtype='object')

# %%
dfc.shape
# Out:
# (10, 8)

# %%
#Merge -- SQL Style

# %%
df21 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds21.csv')
print(df21)
df22 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds22.csv')
print(df22)
# Out:
#                 company stock_name  high  low
# 0        infi_systems13       INFS  1200    600
# 1  kernel_associates123       KRAS  1100    800
# 2      porto_shipping23       POSH  1200    300
# 3     appo_automobiles3       APTP  2000    800
#                 company  vol  rev  exp stock_ticker   HQ
# 0  kernel_associates123  350  450  550         KRAS  Mum
# 1      vv_automobiles12  450  550  500         VVAU  Blr
# 2      porto_shipping23  550  650  700         POSH  Che
# 3          time_makers2  400  300  200         HMTW  Kol
# 4        charmi_studios  500  250  150         CSTD  HYD

# %%
pd.merge(left = df21, right = df22, how='inner', on='company')
# Out:
#                 company stock_name  high  low    vol  rev  exp stock_ticker  \
# 0  kernel_associates123       KRAS  1100    800  350  450  550         KRAS
# 1      porto_shipping23       POSH  1200    300  550  650  700         POSH
#
#     HQ
# 0  Mum
# 1  Che

# %%
pd.merge(left = df21, right = df22, how='outer', on='company')
# Out:
#                 company stock_name    high  low      vol    rev    exp  \
# 0        infi_systems13       INFS  1200.0  600.0    NaN    NaN    NaN
# 1  kernel_associates123       KRAS  1100.0  800.0  350.0  450.0  550.0
# 2      porto_shipping23       POSH  1200.0  300.0  550.0  650.0  700.0
# 3     appo_automobiles3       APTP  2000.0  800.0    NaN    NaN    NaN
# 4      vv_automobiles12        NaN     NaN    NaN  450.0  550.0  500.0
# 5          time_makers2        NaN     NaN    NaN  400.0  300.0  200.0
# 6        charmi_studios        NaN     NaN    NaN  500.0  250.0  150.0
#
#   stock_ticker   HQ
# 0          NaN  NaN
# 1         KRAS  Mum
# 2         POSH  Che
# 3          NaN  NaN
# 4         VVAU  Blr
# 5         HMTW  Kol
# 6         CSTD  HYD

# %%
pd.merge(left = df21, right = df22, how='left', on='company')
# Out:
#                 company stock_name  high  low      vol    rev    exp  \
# 0        infi_systems13       INFS  1200    600    NaN    NaN    NaN
# 1  kernel_associates123       KRAS  1100    800  350.0  450.0  550.0
# 2      porto_shipping23       POSH  1200    300  550.0  650.0  700.0
# 3     appo_automobiles3       APTP  2000    800    NaN    NaN    NaN
#
#   stock_ticker   HQ
# 0          NaN  NaN
# 1         KRAS  Mum
# 2         POSH  Che
# 3          NaN  NaN

# %%
pd.merge(left = df21, right = df22, how='right', on='company')
# Out:
#                 company stock_name    high  low    vol  rev  exp stock_ticker  \
# 0  kernel_associates123       KRAS  1100.0  800.0  350  450  550         KRAS
# 1      porto_shipping23       POSH  1200.0  300.0  550  650  700         POSH
# 2      vv_automobiles12        NaN     NaN    NaN  450  550  500         VVAU
# 3          time_makers2        NaN     NaN    NaN  400  300  200         HMTW
# 4        charmi_studios        NaN     NaN    NaN  500  250  150         CSTD
#
#     HQ
# 0  Mum
# 1  Che
# 2  Blr
# 3  Kol
# 4  HYD

# %%
df23 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds23.csv')
print(df23)
# Out:
#                 company   HQ Catg  empcnt
# 0        infi_systems13  Blr  Pub   20000
# 1      tree_consulting1  NCR  Pub   10000
# 2  kernel_associates123  Mum  Pvt    5000
# 3      vv_automobiles12  Blr  Pvt   30000

# %%
pd.merge(left = df22, right = df23, how='right', on='company')
# Out:
#                 company    vol    rev    exp stock_ticker HQ_x HQ_y Catg  \
# 0  kernel_associates123  350.0  450.0  550.0         KRAS  Mum  Mum  Pvt
# 1      vv_automobiles12  450.0  550.0  500.0         VVAU  Blr  Blr  Pvt
# 2        infi_systems13    NaN    NaN    NaN          NaN  NaN  Blr  Pub
# 3      tree_consulting1    NaN    NaN    NaN          NaN  NaN  NCR  Pub
#
#    empcnt
# 0    5000
# 1   30000
# 2   20000
# 3   10000

# %%
pd.merge(left = df22, right = df23, how='inner', on='HQ')
# Out:
#               company_x  vol  rev  exp stock_ticker   HQ  \
# 0  kernel_associates123  350  450  550         KRAS  Mum
# 1      vv_automobiles12  450  550  500         VVAU  Blr
# 2      vv_automobiles12  450  550  500         VVAU  Blr
#
#               company_y Catg  empcnt
# 0  kernel_associates123  Pvt    5000
# 1        infi_systems13  Pub   20000
# 2      vv_automobiles12  Pvt   30000

# %%
#Pivot Table

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
print(df1)
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance       899  917.0  674  Pub    1443  Mum
# Bombay_Sporting      925  839.8  615  Pvt     154  Mum
# Kolkata_FMCG         900  874.4  676  Pub    1379  Kol
# NCR_Leagles          931  863.5  605  Pub    1935  NCR
# Chennai_Shipping     992  821.0  665  Pub    1154  Che
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che
# Indi_Services        954  733.0  609  Gov   13023  NCR

# %%
df2 = pd.pivot_table(df1, index='Catg')
df2
# Out:
#       EmpCnt    Exp     Rev    Vol
# Catg
# Gov   7192.0  629.5  807.30  942.5
# Pub   1513.4  645.6  867.82  937.6
# Pvt    136.5  755.0  822.40  945.5

# %%
df2 = pd.pivot_table(df1, index='Catg', aggfunc =[np.min, np.max, np.mean])
df2
# Out:
#        amin                         amax                          mean         \
#      EmpCnt  Exp   HQ    Rev  Vol EmpCnt  Exp   HQ    Rev  Vol  EmpCnt    Exp
# Catg
# Gov    1361  609  Blr  733.0  931  13023  650  NCR  881.6  954  7192.0  629.5
# Pub    1154  605  Che  821.0  899   1935  676  NCR  917.0  992  1513.4  645.6
# Pvt     119  615  Blr  805.0  925    154  895  Mum  839.8  966   136.5  755.0
#
#
#          Rev    Vol
# Catg
# Gov   807.30  942.5
# Pub   867.82  937.6
# Pvt   822.40  945.5

# %%
df2 = pd.pivot_table(df1, index='Catg', columns=['HQ'], values=['Exp','Rev'],aggfunc =[np.min, np.max, np.mean])
df2
# Out:
#        amin                                                                 \
#         Exp                                Rev
# HQ      Blr    Che    Kol    Mum    NCR    Blr    Che    Kol    Mum    NCR
# Catg
# Gov   650.0    NaN    NaN    NaN  609.0  881.6    NaN    NaN    NaN  733.0
# Pub     NaN  608.0  676.0  674.0  605.0    NaN  821.0  874.4  917.0  863.5
# Pvt   895.0    NaN    NaN  615.0    NaN  805.0    NaN    NaN  839.8    NaN
#
#       ...   mean                                                          \
#       ...    Exp                                Rev
# HQ    ...    Blr    Che    Kol    Mum    NCR    Blr    Che    Kol    Mum
# Catg  ...
# Gov   ...  650.0    NaN    NaN    NaN  609.0  881.6    NaN    NaN    NaN
# Pub   ...    NaN  636.5  676.0  674.0  605.0    NaN  842.1  874.4  917.0
# Pvt   ...  895.0    NaN    NaN  615.0    NaN  805.0    NaN    NaN  839.8
#
#
#
# HQ      NCR
# Catg
# Gov   733.0
# Pub   863.5
# Pvt     NaN
#
# [3 rows x 30 columns]

# %%
df2 = pd.pivot_table(df1, index='Catg', values='Vol', aggfunc =[np.min, np.max, lambda c:c.max()-c.min()])
df2
# Out:
#      amin amax <lambda>
#       Vol  Vol      Vol
# Catg
# Gov   931  954       23
# Pub   899  992       93
# Pvt   925  966       41

# %% [raw]
# #Groupby
# #Split Apply Combine

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
print(df1)
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance       899  917.0  674  Pub    1443  Mum
# Bombay_Sporting      925  839.8  615  Pvt     154  Mum
# Kolkata_FMCG         900  874.4  676  Pub    1379  Kol
# NCR_Leagles          931  863.5  605  Pub    1935  NCR
# Chennai_Shipping     992  821.0  665  Pub    1154  Che
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che
# Indi_Services        954  733.0  609  Gov   13023  NCR

# %%
dfg = df1.groupby(by='Catg')
print(dfg)
print(type(dfg))
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fec54797880>
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
list(dfg)
# Out:
# [('Gov',
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
#   Bangalore_Systems  931  881.6  650  Gov    1361  Blr
#   Indi_Services      954  733.0  609  Gov   13023  NCR),
#  ('Pub',
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
#   Bombay_Finance     899  917.0  674  Pub    1443  Mum
#   Kolkata_FMCG       900  874.4  676  Pub    1379  Kol
#   NCR_Leagles        931  863.5  605  Pub    1935  NCR
#   Chennai_Shipping   992  821.0  665  Pub    1154  Che
#   Chennai_Chemicals  966  863.2  608  Pub    1656  Che),
#  ('Pvt',
#                        Vol    Rev  Exp Catg  EmpCnt   HQ
#   Bombay_Sporting      925  839.8  615  Pvt     154  Mum
#   Bangalore_Breweries  966  805.0  895  Pvt     119  Blr)]

# %%
df1.groupby(by='Catg')['Vol'].max()
# Out:
# Catg
# Gov    954
# Pub    992
# Pvt    966
# Name: Vol, dtype: int64

# %%
dfg.Vol.max()
# Out:
# Catg
# Gov    954
# Pub    992
# Pvt    966
# Name: Vol, dtype: int64

# %%
df2 = df1.groupby(by=['Catg','HQ']).agg(['min','max',np.mean])
df2
# Out:
#           Vol              Rev                Exp             EmpCnt         \
#           min  max mean    min    max   mean  min  max   mean    min    max
# Catg HQ
# Gov  Blr  931  931  931  881.6  881.6  881.6  650  650  650.0   1361   1361
#      NCR  954  954  954  733.0  733.0  733.0  609  609  609.0  13023  13023
# Pub  Che  966  992  979  821.0  863.2  842.1  608  665  636.5   1154   1656
#      Kol  900  900  900  874.4  874.4  874.4  676  676  676.0   1379   1379
#      Mum  899  899  899  917.0  917.0  917.0  674  674  674.0   1443   1443
#      NCR  931  931  931  863.5  863.5  863.5  605  605  605.0   1935   1935
# Pvt  Blr  966  966  966  805.0  805.0  805.0  895  895  895.0    119    119
#      Mum  925  925  925  839.8  839.8  839.8  615  615  615.0    154    154
#
#
#            mean
# Catg HQ
# Gov  Blr   1361
#      NCR  13023
# Pub  Che   1405
#      Kol   1379
#      Mum   1443
#      NCR   1935
# Pvt  Blr    119
#      Mum    154

# %%
#Stack, Unstack

# %%
n48 = np.random.randint(10, 100, size=(4,8) )
print(n48)
# Out:
# [[57 49 41 53 54 21 63 75]
#  [36 44 18 21 47 53 12 88]
#  [90 88 63 23 67 62 78 17]
#  [61 35 63 98 72 36 46 48]]

# %%
indexlist = ['Tata', 'Birla', 'Wipro', 'ITC']
print(indexlist)
# Out:
# ['Tata', 'Birla', 'Wipro', 'ITC']

# %%
level0_col_labels = [2018, 2019]
level1_col_labels = ['Q1','Q2']
level2_col_labels = ['FMCG', 'Tech']

# %%
clist = pd.MultiIndex.from_product([level0_col_labels, level1_col_labels, level2_col_labels])
print(clist)
# Out:
# MultiIndex([(2018, 'Q1', 'FMCG'),
#             (2018, 'Q1', 'Tech'),
#             (2018, 'Q2', 'FMCG'),
#             (2018, 'Q2', 'Tech'),
#             (2019, 'Q1', 'FMCG'),
#             (2019, 'Q1', 'Tech'),
#             (2019, 'Q2', 'FMCG'),
#             (2019, 'Q2', 'Tech')],
#            )

# %%
df1 = pd.DataFrame(n48, index=indexlist, columns=clist)
df1
# Out:
#       2018                2019
#         Q1        Q2        Q1        Q2
#       FMCG Tech FMCG Tech FMCG Tech FMCG Tech
# Tata    57   49   41   53   54   21   63   75
# Birla   36   44   18   21   47   53   12   88
# Wipro   90   88   63   23   67   62   78   17
# ITC     61   35   63   98   72   36   46   48

# %%
df1.stack(1)
# Out:
#          2018      2019
#          FMCG Tech FMCG Tech
# Tata  Q1   57   49   54   21
#       Q2   41   53   63   75
# Birla Q1   36   44   47   53
#       Q2   18   21   12   88
# Wipro Q1   90   88   67   62
#       Q2   63   23   78   17
# ITC   Q1   61   35   72   36
#       Q2   63   98   46   48

# %%
df1.unstack()
# Out:
# 2018  Q1  FMCG  Tata     57
#                 Birla    36
#                 Wipro    90
#                 ITC      61
#           Tech  Tata     49
#                 Birla    44
#                 Wipro    88
#                 ITC      35
#       Q2  FMCG  Tata     41
#                 Birla    18
#                 Wipro    63
#                 ITC      63
#           Tech  Tata     53
#                 Birla    21
#                 Wipro    23
#                 ITC      98
# 2019  Q1  FMCG  Tata     54
#                 Birla    47
#                 Wipro    67
#                 ITC      72
#           Tech  Tata     21
#                 Birla    53
#                 Wipro    62
#                 ITC      36
#       Q2  FMCG  Tata     63
#                 Birla    12
#                 Wipro    78
#                 ITC      46
#           Tech  Tata     75
#                 Birla    88
#                 Wipro    17
#                 ITC      48
# dtype: int64

# %%
df1
# Out:
#       2018                2019
#         Q1        Q2        Q1        Q2
#       FMCG Tech FMCG Tech FMCG Tech FMCG Tech
# Tata    57   49   41   53   54   21   63   75
# Birla   36   44   18   21   47   53   12   88
# Wipro   90   88   63   23   67   62   78   17
# ITC     61   35   63   98   72   36   46   48

# %%
#Map

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
print(df1)
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance       899  917.0  674  Pub    1443  Mum
# Bombay_Sporting      925  839.8  615  Pvt     154  Mum
# Kolkata_FMCG         900  874.4  676  Pub    1379  Kol
# NCR_Leagles          931  863.5  605  Pub    1935  NCR
# Chennai_Shipping     992  821.0  665  Pub    1154  Che
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che
# Indi_Services        954  733.0  609  Gov   13023  NCR

# %%
c2z = {'Mum':'WZ', 'Kol':'EZ', 'Blr':'SZ', 'Che':'SZ', 'NCR':'NZ'}

# %%
df1['Zone'] = df1['HQ'].map(c2z)
df1
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ Zone
# Bombay_Finance       899  917.0  674  Pub    1443  Mum   WZ
# Bombay_Sporting      925  839.8  615  Pvt     154  Mum   WZ
# Kolkata_FMCG         900  874.4  676  Pub    1379  Kol   EZ
# NCR_Leagles          931  863.5  605  Pub    1935  NCR   NZ
# Chennai_Shipping     992  821.0  665  Pub    1154  Che   SZ
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr   SZ
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr   SZ
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che   SZ
# Indi_Services        954  733.0  609  Gov   13023  NCR   NZ

# %%
def salesclassifier(sale_value):
    if sale_value > 950:
        return 'Excellent_Sales'
    elif sale_value < 930:
        return 'Average_Sales'
    else:
        return 'Good_Sales'

# %%
df1['Vol_Class'] = df1['Vol'].map(salesclassifier)
df1
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ Zone        Vol_Class
# Bombay_Finance       899  917.0  674  Pub    1443  Mum   WZ    Average_Sales
# Bombay_Sporting      925  839.8  615  Pvt     154  Mum   WZ    Average_Sales
# Kolkata_FMCG         900  874.4  676  Pub    1379  Kol   EZ    Average_Sales
# NCR_Leagles          931  863.5  605  Pub    1935  NCR   NZ       Good_Sales
# Chennai_Shipping     992  821.0  665  Pub    1154  Che   SZ  Excellent_Sales
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr   SZ       Good_Sales
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr   SZ  Excellent_Sales
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che   SZ  Excellent_Sales
# Indi_Services        954  733.0  609  Gov   13023  NCR   NZ  Excellent_Sales

# %%
# Drops

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
print(df1)
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance       899  917.0  674  Pub    1443  Mum
# Bombay_Sporting      925  839.8  615  Pvt     154  Mum
# Kolkata_FMCG         900  874.4  676  Pub    1379  Kol
# NCR_Leagles          931  863.5  605  Pub    1935  NCR
# Chennai_Shipping     992  821.0  665  Pub    1154  Che
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che
# Indi_Services        954  733.0  609  Gov   13023  NCR

# %%
df1.drop('Rev', axis = 1)
# Out:
#                      Vol  Exp Catg  EmpCnt   HQ
# Bombay_Finance       899  674  Pub    1443  Mum
# Bombay_Sporting      925  615  Pvt     154  Mum
# Kolkata_FMCG         900  676  Pub    1379  Kol
# NCR_Leagles          931  605  Pub    1935  NCR
# Chennai_Shipping     992  665  Pub    1154  Che
# Bangalore_Systems    931  650  Gov    1361  Blr
# Bangalore_Breweries  966  895  Pvt     119  Blr
# Chennai_Chemicals    966  608  Pub    1656  Che
# Indi_Services        954  609  Gov   13023  NCR

# %%
df1
# Out:
#                      Vol    Rev  Exp Catg  EmpCnt   HQ
# Bombay_Finance       899  917.0  674  Pub    1443  Mum
# Bombay_Sporting      925  839.8  615  Pvt     154  Mum
# Kolkata_FMCG         900  874.4  676  Pub    1379  Kol
# NCR_Leagles          931  863.5  605  Pub    1935  NCR
# Chennai_Shipping     992  821.0  665  Pub    1154  Che
# Bangalore_Systems    931  881.6  650  Gov    1361  Blr
# Bangalore_Breweries  966  805.0  895  Pvt     119  Blr
# Chennai_Chemicals    966  863.2  608  Pub    1656  Che
# Indi_Services        954  733.0  609  Gov   13023  NCR

# %%
#Nan Handling

# %%
df0 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds0.csv')
print(df0)
# Out:
#                      Vol    Rev  Exp Catg   EmpCnt   HQ
# Bombay_Finance       899  917.0  674  Pub   1443.0  Mum
# Bombay_Sporting      925  839.8  615  Pvt    154.0  Mum
# Kolkata_FMCG         900    NaN  676  Pub      NaN  Kol
# NCR_Leagles          931  863.5  605  Pub   1935.0  NCR
# Chennai_Shipping     992  821.0  665  Pub   1154.0  Che
# Bangalore_Systems    931    NaN  650  Gov   1361.0  Blr
# Bangalore_Breweries  966  805.0  895  NaN    119.0  Blr
# Chennai_Chemicals    966  863.2  608  Pub   1656.0  Che
# Indi_Services        954  733.0  609  Gov  13023.0  NCR

# %%
df0.Rev.fillna(df0.Rev.mean(), inplace=True)
df0
# Out:
#                      Vol         Rev  Exp Catg   EmpCnt   HQ
# Bombay_Finance       899  917.000000  674  Pub   1443.0  Mum
# Bombay_Sporting      925  839.800000  615  Pvt    154.0  Mum
# Kolkata_FMCG         900  834.642857  676  Pub      NaN  Kol
# NCR_Leagles          931  863.500000  605  Pub   1935.0  NCR
# Chennai_Shipping     992  821.000000  665  Pub   1154.0  Che
# Bangalore_Systems    931  834.642857  650  Gov   1361.0  Blr
# Bangalore_Breweries  966  805.000000  895  NaN    119.0  Blr
# Chennai_Chemicals    966  863.200000  608  Pub   1656.0  Che
# Indi_Services        954  733.000000  609  Gov  13023.0  NCR

# %%
df0.EmpCnt.fillna(df0.EmpCnt.median(), inplace=True)
df0
# Out:
#                      Vol         Rev  Exp Catg   EmpCnt   HQ
# Bombay_Finance       899  917.000000  674  Pub   1443.0  Mum
# Bombay_Sporting      925  839.800000  615  Pvt    154.0  Mum
# Kolkata_FMCG         900  834.642857  676  Pub   1402.0  Kol
# NCR_Leagles          931  863.500000  605  Pub   1935.0  NCR
# Chennai_Shipping     992  821.000000  665  Pub   1154.0  Che
# Bangalore_Systems    931  834.642857  650  Gov   1361.0  Blr
# Bangalore_Breweries  966  805.000000  895  NaN    119.0  Blr
# Chennai_Chemicals    966  863.200000  608  Pub   1656.0  Che
# Indi_Services        954  733.000000  609  Gov  13023.0  NCR

# %%
df0.Catg.fillna(method='ffill')
df0
# Out:
#                      Vol         Rev  Exp Catg   EmpCnt   HQ
# Bombay_Finance       899  917.000000  674  Pub   1443.0  Mum
# Bombay_Sporting      925  839.800000  615  Pvt    154.0  Mum
# Kolkata_FMCG         900  834.642857  676  Pub   1402.0  Kol
# NCR_Leagles          931  863.500000  605  Pub   1935.0  NCR
# Chennai_Shipping     992  821.000000  665  Pub   1154.0  Che
# Bangalore_Systems    931  834.642857  650  Gov   1361.0  Blr
# Bangalore_Breweries  966  805.000000  895  NaN    119.0  Blr
# Chennai_Chemicals    966  863.200000  608  Pub   1656.0  Che
# Indi_Services        954  733.000000  609  Gov  13023.0  NCR

# %%
df0.Catg.fillna(method='bfill')
df0
# Out:
#                      Vol         Rev  Exp Catg   EmpCnt   HQ
# Bombay_Finance       899  917.000000  674  Pub   1443.0  Mum
# Bombay_Sporting      925  839.800000  615  Pvt    154.0  Mum
# Kolkata_FMCG         900  834.642857  676  Pub   1402.0  Kol
# NCR_Leagles          931  863.500000  605  Pub   1935.0  NCR
# Chennai_Shipping     992  821.000000  665  Pub   1154.0  Che
# Bangalore_Systems    931  834.642857  650  Gov   1361.0  Blr
# Bangalore_Breweries  966  805.000000  895  NaN    119.0  Blr
# Chennai_Chemicals    966  863.200000  608  Pub   1656.0  Che
# Indi_Services        954  733.000000  609  Gov  13023.0  NCR

# %%
#Melting

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/temp246_a.csv')
print(df1)
# Out:
#     Location Temperature  Jan2019  Feb2019  Mar2019
# 0  Bangalore     Predict       23       25       28
# 1    Chennai      Actual       32       34       36

# %%
pd.melt(df1, id_vars = ['Location', 'Temperature'] )
# Out:
#     Location Temperature variable  value
# 0  Bangalore     Predict  Jan2019     23
# 1    Chennai      Actual  Jan2019     32
# 2  Bangalore     Predict  Feb2019     25
# 3    Chennai      Actual  Feb2019     34
# 4  Bangalore     Predict  Mar2019     28
# 5    Chennai      Actual  Mar2019     36

# %%
pd.melt(df1, id_vars = ['Location', 'Temperature'], var_name = 'melted_col_columns', value_name='melted_col_values' )
# Out:
#     Location Temperature melted_col_columns  melted_col_values
# 0  Bangalore     Predict            Jan2019                 23
# 1    Chennai      Actual            Jan2019                 32
# 2  Bangalore     Predict            Feb2019                 25
# 3    Chennai      Actual            Feb2019                 34
# 4  Bangalore     Predict            Mar2019                 28
# 5    Chennai      Actual            Mar2019                 36
